# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit116.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greats={'유비':89,'관우':95,'장비':91,'조운':94}
generals=greats.items()
print(list(generals))
# Out:
# [('유비', 89), ('관우', 95), ('장비', 91), ('조운', 94)]

# %%
del greats['관우']
print(list(generals))
# Out:
# [('유비', 89), ('장비', 91), ('조운', 94)]
