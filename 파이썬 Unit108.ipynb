# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit108.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nameList=['Mary','Cris','Aimy','Tom','Bob']
population=[10999,2111,9778,20245,27115]
names={}      #빈 딕셔너리 정의
for k, v in zip(nameList,population):
  names[k]=v
  print(names)
# Out:
# {'Mary': 10999}
# {'Mary': 10999, 'Cris': 2111}
# {'Mary': 10999, 'Cris': 2111, 'Aimy': 9778}
# {'Mary': 10999, 'Cris': 2111, 'Aimy': 9778, 'Tom': 20245}
# {'Mary': 10999, 'Cris': 2111, 'Aimy': 9778, 'Tom': 20245, 'Bob': 27115}

# %%
names['Mary']=20000
print(names)
# Out:
# {'Mary': 20000, 'Cris': 2111, 'Aimy': 9778, 'Tom': 20245, 'Bob': 27115}
