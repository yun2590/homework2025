# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = {'사과','배','오렌지','수박'}
choise = fruits.pop()
print(f'++추출한 요소: {choise}\n++fruits: {fruits}')
# Out:
# ++추출한 요소: 사과
# ++fruits: {'오렌지', '수박', '배'}

# %%
for _ in range(len(fruits)):
  choise = fruits.pop()
  print(f'++추출한 요소: {choise}\n++fruits: {fruits}')
choise = fruits.pop()
# Out:
# ++추출한 요소: 오렌지
# ++fruits: {'수박', '배'}
# ++추출한 요소: 수박
# ++fruits: {'배'}
# ++추출한 요소: 배
# ++fruits: set()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-420535320.py in <cell line: 0>()
#       2   choise = fruits.pop()
#       3   print(f'++추출한 요소: {choise}\n++fruits: {fruits}')
# ----> 4 choise = fruits.pop()
#
# KeyError: 'pop from an empty set'
