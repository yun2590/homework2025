# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit124.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def func():       #func은 사용자가 정의하는 함수 이름
  코드
  return
#함수 호출 방법
func()

# %%
def func(매개변수1, 매개변수2,...):
  코드
  return
#함수 호출 방법
func(인자1, 인자2, ...)

# %%
def func():
  코드
  return 리턴값
#함수 호출 방법
<리턴값을 받을 변수> = func()

# %%
def func(매개변수1, 매개변수2,...):
  코드
  return 리턴값
#함수 호출 방법
<리턴값을 받을 변수> = func(인자1, 인자2, ...)

# %%
def displayFilepath():
  filepath='c:/myworks/pythonstrudy.py'
  print(f'파일경로: {filepath}')
  return

displayFilepath()
# Out:
# 파일경로: c:/myworks/pythonstrudy.py

# %%
def printFilepath(folder, filename):
  print(f'파일경로: {folder+filename}')


printFilepath('c:/mywork/','pythonstudy.py')
# Out:
# 파일경로: c:/mywork/pythonstudy.py

# %%
def getFilepath():
  filepath = 'c:/myworks/pythonstrudy.py'
  return filepath

filepath = makeFilepath()
print(f'파일경로: {filepath}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-726782698.py in <cell line: 0>()
#       3   return filepath
#       4
# ----> 5 filepath = makeFilepath()
#       6 print(f'파일경로: {filepath}')
#
# TypeError: makeFilepath() missing 2 required positional arguments: 'folder' and 'filename'

# %%
def makeFilepath(folder, filename):
  return folder+filename

filepath = getFilepath('c:/mywork/','pythonstudy.py')
print(f'파일경로: {filepath}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-571222553.py in <cell line: 0>()
#       2   return folder+filename
#       3
# ----> 4 filepath = getFilepath('c:/mywork/','pythonstudy.py')
#       5 print(f'파일경로: {filepath}')
#
# TypeError: getFilepath() takes 0 positional arguments but 2 were given
