# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit106.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = {'Mary':10999,'Cris':2111,'Aimy':9778,'Tom':20245}
ret1=names.get('Cris')
ret2=names.get('Sams')

# %%
ret1=names.get('Cris',0)
ret2=names.get('Sams',0)
print(f'ret1={ret1},ret2={ret2}')
# Out:
# ret1=2111,ret2=0
