# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit104.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
population={'서울':9407540, '부산':3320276, '인천':2964820}

# %%
population=dict(서울=9407540, 부산=3320276, 인천=2964820)
print(population)
# Out:
# {'서울': 9407540, '부산': 3320276, '인천': 2964820}

# %%
population=dict([('서울',9407540),('부산',3320276),('인천',2964820)])
print(population)
# Out:
# {'서울': 9407540, '부산': 3320276, '인천': 2964820}
