# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit130.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def report():
  print('이 부분은 리포트의 본문입니다.')

# %%
def makeNumber():
  for i in range(3):
    print(i)

# %%
report()
# Out:
# 이 부분은 리포트의 본문입니다.

# %%
makeNumber()
# Out:
# 0
# 1
# 2

# %%
def report1():
  print('-'*50)
  print('이 부분은 리포트의 본문입니다.')
  print('-'*50)
  return

def makeNumber1():
  print('-'*50)
  for i in range(3):
    print(i)
  print('-'*50)
  return

# %%
def makeForm(func):
  def drawLine():
    print('-'*50)
    func()
    print('-'*50)
  return drawLine

# %%
report_new=makeForm(report)
report_new()
# Out:
# --------------------------------------------------
# 이 부분은 리포트의 본문입니다.
# --------------------------------------------------

# %%
def drawLine():
    print('-'*50)
    report()
    print('-'*50)

# %%
makeNumber_new = makeForm(makeNumber)
makeNumber_new()
# Out:
# --------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3638227713.py in <cell line: 0>()
#       1 makeNumber_new = makeForm(makeNumber)
# ----> 2 makeNumber_new()
#
# /tmp/ipython-input-3509632465.py in drawLine()
#       2   def drawLine():
#       3     print('-'*50)
# ----> 4     func()
#       5     print('-'*50)
#       6   return drawLine
#
# TypeError: makeNumber() missing 1 required positional argument: 'func'

# %%
@makeForm
def report():
  print('이 부분은 리포트의 본문입니다.')
  return

# %%
ret=makeForm(report)
ret()
# Out:
# --------------------------------------------------
# --------------------------------------------------
# 이 부분은 리포트의 본문입니다.
# --------------------------------------------------
# --------------------------------------------------

# %%
report_new=makeForm(report)
report_new
# Out:
# <function __main__.makeForm.<locals>.drawLine()>

# %%
report()
# Out:
# --------------------------------------------------
# 이 부분은 리포트의 본문입니다.
# --------------------------------------------------

# %%
def decoFunc(func):
  def wrapper(*args, **kwargs):
    #공통 기능 수행 코드
     func(*args, **kwargs)
    #공통 기능 수행 코드
  return wrapper
