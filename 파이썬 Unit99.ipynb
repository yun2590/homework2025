# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = {'사과','배','오렌지','수박'}
fruits.add('딸기')
print(fruits)
# Out:
# {'딸기', '오렌지', '배', '사과', '수박'}

# %%
fruits.add('배')
print(fruits)
# Out:
# {'딸기', '오렌지', '배', '사과', '수박'}
