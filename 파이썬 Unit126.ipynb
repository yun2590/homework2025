# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit126.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
param=10
def func1(param):
  localData=5
  print(f'param={param}')
  return

func1(5)
print(f'param={param}')
# Out:
# param=5
# param=10

# %%
param=10
def func2():
  param=20
  return param

ret=func2() #ret의 값은 20입니다.
print(f'param={param}')
# Out:
# param=10

# %%
param=10
def func3():
  global param  #전역변수 param임을 명시함
  param=20
  return

func3()
print(f'param={param}')
# Out:
# param=20
