# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit114.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greats={'유비':89,'관우':95,'장비':91,'조운':94}
greats.clear()
print(greats)
# Out:
# {}

# %%
greats={'유비':89,'관우':95,'장비':91,'조운':94}
del greats
print(greats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3576612504.py in <cell line: 0>()
#       1 greats={'유비':89,'관우':95,'장비':91,'조운':94}
#       2 del greats
# ----> 3 print(greats)
#
# NameError: name 'greats' is not defined
