# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names={'Mary':10999,'Cris':2111,'Aimy':9778,'Tom':20245}
del names['Mary']
print(names)
# Out:
# {'Cris': 2111, 'Aimy': 9778, 'Tom': 20245}

# %%
del names['Sams']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3085454307.py in <cell line: 0>()
# ----> 1 del names['Sams']
#
# KeyError: 'Sams'
