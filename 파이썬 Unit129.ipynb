# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit129.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def setLevel(character: str, level: int)->dict[str,int]:
  return{character:level}

# %%
def setLevel(character: str, level: int)->None:
  global greats
  greats[character]=level
  return

# %%
greats={'유비':10,'관우':15,'장비':10}
setLevel('유비',13)
print(greats)
# Out:
# {'유비': 13, '관우': 15, '장비': 10}
