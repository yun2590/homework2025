# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit105.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
population={'서울':9407540, '부산':3320276, '인천':2964820}
pnum=population['서울']
print(f'2022년 기준 서울의 인구는 {pnum:,d}명 입니다.')
# Out:
# 2022년 기준 서울의 인구는 9,407,540명 입니다.

# %%
orddict={97:'a',98:'b',99:'c'}
print(f'ASCII 코드 97은 문자 {orddict[97]}에 대응됩니다.')
# Out:
# ASCII 코드 97은 문자 a에 대응됩니다.

# %%
ret=orddict[95]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3624175959.py in <cell line: 0>()
# ----> 1 ret=orddict[95]
#
# KeyError: 95
