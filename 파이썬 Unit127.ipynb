# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit127.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def reverse(*args):
  result=[]
  idx=len(args)-1
  while idx>=0:
    result.append(args[idx])
    idx -=1
  return result

# %%
ret = reverse('가','나','다','라')
print(ret)
# Out:
# ['라', '다', '나', '가']
