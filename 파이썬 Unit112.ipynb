# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit112.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
frequency={}
while True:
  c=input('알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]: ')
  if c == '':
    break
  if c not in frequency:
    frequency[c]=1
  else:
    frequency[c]+=1
  print(frequency)
# Out:
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]: a
# {'a': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]: b
# {'a': 1, 'b': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]: c
# {'a': 1, 'b': 1, 'c': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]: a
# {'a': 2, 'b': 1, 'c': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]: c
# {'a': 2, 'b': 1, 'c': 2}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:
