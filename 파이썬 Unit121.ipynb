# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/homework2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit121.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greats={'유비':89,'관우':95,'장비':91,'조운':94}
others={'제갈량':99,'황충':70}
greats.update(others)
print(greats)
# Out:
# {'유비': 89, '관우': 95, '장비': 91, '조운': 94, '제갈량': 99, '황충': 70}

# %%
greats.update(유비=90,관우=96)
print(greats)
# Out:
# {'유비': 90, '관우': 96, '장비': 91, '조운': 94, '제갈량': 99, '황충': 70}
