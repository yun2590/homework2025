# %% [markdown]
# <a href="https://colab.research.google.com/github/yun2590/Exercise_2025/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%20Unit128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f=lambda x: x**2
print(f(2))
print(f(3))
# Out:
# 4
# 9

# %%
f=lambda x: x+'.txt'
print(f('readme'))
# Out:
# readme.txt

# %%
f=lambda x: x[1]
print(f('readme'))
print(f(('장비',10)))
# Out:
# e
# 10
